# %%
import project_image_in_video as piv

# %%
video = '../Samples/posSamplesTable.MOV'
img_to_project = '../Samples/128orangutan.jpg'
piv.project_img(video, img_to_project, line_thresh=100)
# Out:
# 76.38996982574463
